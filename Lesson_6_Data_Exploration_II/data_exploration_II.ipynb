# %%
# import libraries
import pandas as pd 
import numpy as np

data_ources = "https://towardsdatascience.com/all-the-datasets-you-need-to-practice-data-science-skills-and-make-a-great-portfolio-857a348883b5"
    
# import housing dataset
df_housing_data = pd.read_csv("home_data.csv") 

df_housing_data.head(5)
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## Data Constrains
# - Raw data needs to be processed most of the time because raw data is always contaminated and unorganized
#
# ### Review of data types constrains
#
# Remember that in python data is divided into data types...
#
# ![data_types.PNG](attachment:data_types.PNG)
#
#
# - One of the first steps in data exploration process is to verify that the data has the correct data types
# -

# %%
### Range Constrains
- For floors field to have decimal points, or the zipcode to have 3 digits

# %%
### Uniqueness Constrains

## Text and Categorical Problems
### Categorical Variables
### Cleaning Text Data

## Uniformity
### Cross Field Validation
### Missing Values
